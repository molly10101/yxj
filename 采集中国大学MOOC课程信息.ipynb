# %%
import requests
from bs4 import BeautifulSoup
import re
import time
from selenium import webdriver
import pandas as pd
import csv

###爬取课程页信息###
def GetDetail(url,result):
    
    driver=webdriver.Chrome()
    driver.get(url)
    time.sleep(2)
    html=driver.page_source
    bsobject=BeautifulSoup(html,"lxml")

    #print(bsobject)
    course_name=bsobject.find(class_="course-title f-ib f-vam").get_text()
    result.append(course_name)
    subject=bsobject.find(class_="breadcrumb_item sub-category").get_text()
    result.append(subject)
    num_of_join=bsobject.find(class_="course-enroll-info_course-enroll_price-enroll_enroll-count").get_text()
    result.append(num_of_join.split()[1])
    num_of_mark=bsobject.find(id="review-tag-num").get_text()
    result.append(num_of_mark[1:-1])
    a = driver.find_element_by_id("review-tag-button") 
    a.click()
    time.sleep(2)
    html=driver.page_source
    bsobject=BeautifulSoup(html,"lxml")
    star=bsobject.find(class_="ux-mooc-comment-course-comment_head_rating-scores")
    #print(star)
    if star is not None:
        result.append(star.get_text())
        #print(star.get_text())
    else:
        result.append("")
    driver.close()
    #print(cont4)
#url="https://www.icourse163.org/course/WHU-1457456166"
#GetDetail(url)



###爬取单个页面###
def getHTMLText(url):
    try:
        time.sleep(3)
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""
###爬取首页所有高校页面链接###
def getSchoolURLs():
    school_ls=[]
    school_url_ls=[]
    
    html=getHTMLText(base_url)
    soup=BeautifulSoup(html)
    for link in soup.body.findAll(class_='u-usity f-fl'):
        if 'href' in link.attrs:
            #print(link.attrs['href'])
            school_ls.append(link.attrs['href'])
    #print(school_ls)
    for item in school_ls:
        school_url_ls.append("https://www.icourse163.org"+item+"#/c")
    return school_url_ls
#print(school_url_ls)
#生成目标学校url



base_url="https://www.icourse163.org/university/view/all.htm#/" #首页url
SchoolURLs=getSchoolURLs() #得到存放了所有大学页面url的列表
print(SchoolURLs)  #成功

###打开csv文件，写入文件头
headers_of_csv=["学校","课程名称","科目","参加人数","评价人数","评分"]
csvFile=open("中国大学MOOC课程信息3.csv","w+",newline='',encoding='utf-8')
f_csv=csv.writer(csvFile)
f_csv.writerow(headers_of_csv)

results=[]  #数组存放学校，课程名，科目，参与人数，评价人数，评分

for school in SchoolURLs: 
    print("在读取的学校是：{}".format(school))
    course_ls=[]
    course_url_ls=[]
    driver=webdriver.Chrome() #打开浏览器
    def OpenSchoolWeb(url):  
        driver.get(url)
        time.sleep(3)
        html=driver.page_source
        bsobject=BeautifulSoup(html,"lxml")
        cont=bsobject.findAll(class_="u-courseCardWithTime-container_a160") 
        for items in cont:
            if 'href' in items.attrs: 
                if items.attrs['href'] in course_ls:
                    return
                course_ls.append(items.attrs['href']) #找到课程链接 
        for items in course_ls:
            course_url_ls.append("https:"+items) #构造完整url
        try:
            a = driver.find_element_by_link_text("下一页")  #翻页
            a.click()
            time.sleep(3)
        except:
            return
        OpenSchoolWeb(url)

    OpenSchoolWeb(school)   #打开该学校页面并获取所有课程
    driver.close()   #关闭浏览器
    
    CourseURLs=set(course_url_ls) #去重
    print("找到{}门课程".format(len(CourseURLs)))
    
    for course in CourseURLs:
        print("在读取的课程是：{}".format(course))
        result=[]
        result.append(str(school)[38:-3])  #第一个元素是该课程开设的高校
        GetDetail(course,result) #爬取课程页面信息
        f_csv.writerow(result) #写入数据
        print(result) #成功
csvFile.close  #结束关闭csv文件
# Out:
# ['https://www.icourse163.org/university/PKU#/c', 'https://www.icourse163.org/university/NJU#/c', 'https://www.icourse163.org/university/ZJU#/c', 'https://www.icourse163.org/university/FUDAN#/c', 'https://www.icourse163.org/university/BUAA#/c', 'https://www.icourse163.org/university/WHU#/c', 'https://www.icourse163.org/university/BIT#/c', 'https://www.icourse163.org/university/CAU#/c', 'https://www.icourse163.org/university/BNU#/c', 'https://www.icourse163.org/university/MUC#/c', 'https://www.icourse163.org/university/NKU#/c', 'https://www.icourse163.org/university/TJU#/c', 'https://www.icourse163.org/university/DUT#/c', 'https://www.icourse163.org/university/JLU#/c', 'https://www.icourse163.org/university/HIT#/c', 'https://www.icourse163.org/university/NEU#/c', 'https://www.icourse163.org/university/TONGJI#/c', 'https://www.icourse163.org/university/SJTU#/c', 'https://www.icourse163.org/university/ECNU#/c', 'https://www.icourse163.org/university/RUC#/c', 'https://www.icourse163.org/university/SEU#/c', 'https://www.icourse163.org/university/USTC#/c', 'https://www.icourse163.org/university/XMU#/c', 'https://www.icourse163.org/university/SDU#/c', 'https://www.icourse163.org/university/OUC#/c', 'https://www.icourse163.org/university/HUST#/c', 'https://www.icourse163.org/university/HNU#/c', 'https://www.icourse163.org/university/CSU#/c', 'https://www.icourse163.org/university/NUDT#/c', 'https://www.icourse163.org/university/SYSU#/c', 'https://www.icourse163.org/university/SCUT#/c', 'https://www.icourse163.org/university/SCU#/c', 'https://www.icourse163.org/university/CQU#/c', 'https://www.icourse163.org/university/UESTC#/c', 'https://www.icourse163.org/university/XJTU#/c', 'https://www.icourse163.org/university/NWPU#/c', 'https://www.icourse163.org/university/NWSUAF#/c', 'https://www.icourse163.org/university/LZU#/c', 'https://www.icourse163.org/university/bjut#/c', 'https://www.icourse163.org/university/CUFE#/c', 'https://www.icourse163.org/university/cupl#/c', 'https://www.icourse163.org/university/BUPT#/c', 'https://www.icourse163.org/university/NJTU#/c', 'https://www.icourse163.org/university/BUCM#/c', 'https://www.icourse163.org/university/NCEPU#/c', 'https://www.icourse163.org/university/USTB#/c', 'https://www.icourse163.org/university/CUP#/c', 'https://www.icourse163.org/university/BFSU#/c', 'https://www.icourse163.org/university/BUCT#/c', 'https://www.icourse163.org/university/UIBE#/c', 'https://www.icourse163.org/university/CCOM#/c', 'https://www.icourse163.org/university/BFU#/c', 'https://www.icourse163.org/university/CUMTB#/c', 'https://www.icourse163.org/university/BSU#/c', 'https://www.icourse163.org/university/CUC#/c', 'https://www.icourse163.org/university/ZGDZDXBJ#/c', 'https://www.icourse163.org/university/HEBUT#/c', 'https://www.icourse163.org/university/TJYKDX#/c', 'https://www.icourse163.org/university/SISU#/c', 'https://www.icourse163.org/university/tufc#/c', 'https://www.icourse163.org/university/DHU#/c', 'https://www.icourse163.org/university/ECUST#/c', 'https://www.icourse163.org/university/SHU#/c', 'https://www.icourse163.org/university/SWU#/c', 'https://www.icourse163.org/university/NCEPUB#/c', 'https://www.icourse163.org/university/TYUT#/c', 'https://www.icourse163.org/university/IMU#/c', 'https://www.icourse163.org/university/DLMU#/c', 'https://www.icourse163.org/university/NENU#/c', 'https://www.icourse163.org/university/NEFU#/c', 'https://www.icourse163.org/university/HRBEU#/c', 'https://www.icourse163.org/university/NEAU#/c', 'https://www.icourse163.org/university/JIANGNAN#/c', 'https://www.icourse163.org/university/NUAA#/c', 'https://www.icourse163.org/university/CUMT#/c', 'https://www.icourse163.org/university/SUDA#/c', 'https://www.icourse163.org/university/NJUST#/c', 'https://www.icourse163.org/university/NJNU#/c', 'https://www.icourse163.org/university/CPU#/c', 'https://www.icourse163.org/university/HHU#/c', 'https://www.icourse163.org/university/NJAU#/c', 'https://www.icourse163.org/university/H ...
# 在读取的学校是：https://www.icourse163.org/university/PKU#/c
# 找到95门课程
# 在读取的课程是：https://www.icourse163.org/course/PKU-1002029030
# ['PKU', '程序设计与算法（三）C++面向对象程序设计', '国家精品', '20717', '1008', '4.9']
# 在读取的课程是：https://www.icourse163.org/course/PKU-1003769005
# ['PKU', '中国近现代史纲要', '法学', '59296', '1019', '4.6']
# 在读取的课程是：https://www.icourse163.org/course/PKU-1003479006
# ['PKU', 'Python语言基础与应用', '计算机', '52511', '1012', '4.8']
# 在读取的课程是：https://www.icourse163.org/course/PKU-1002530002
# ['PKU', '微积分基础', '理学', '6992', '226', '4.8']
# 在读取的课程是：https://www.icourse163.org/course/PKU-1003090003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8f28467cbb77> in <module>
#     122         result=[]
#     123         result.append(str(school)[38:-3])  #第一个元素是该课程开设的高校
# --> 124         GetDetail(course,result) #爬取课程页面信息
#     125         f_csv.writerow(result) #写入数据
#     126         print(result) #成功
#
# <ipython-input-2-8f28467cbb77> in GetDetail(url, result)
#      13     driver.get(url)
#      14     time.sleep(2)
# ---> 15     html=driver.page_source
#      16     bsobject=BeautifulSoup(html,"lxml")
#      17
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      74         if method in self._encode_url_methods:
#      75             return self.request_encode_url(
# ---> 76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#      78         else:
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
